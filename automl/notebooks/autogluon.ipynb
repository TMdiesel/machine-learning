# %% [markdown]
# ## overview

# %%
# default package
import logging
import sys 
import os
import pathlib
import IPython
import random
from urllib.request import urlretrieve
import dataclasses as dc
import tempfile

# %%
# third party package
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.font_manager import FontProperties
import matplotlib
from autogluon.tabular import TabularDataset, TabularPredictor

# %%
# my package
sys.path.append(os.path.join(pathlib.Path().resolve(),"../"))

# %%
# reload settings
# %load_ext autoreload
# %autoreload 2

# %%
# logger
logger=logging.getLogger(__name__)
logging.basicConfig(level=logging.INFO)

# %%
# graph setting
sns.set()
font_path = "/usr/share/fonts/truetype/migmix/migmix-1p-regular.ttf"
font_prop = FontProperties(fname=font_path)
matplotlib.rcParams["font.family"] = font_prop.get_name()

# %% [markdown]
# ## load train data

# %%
train_data=TabularDataset('https://autogluon.s3.amazonaws.com/datasets/Inc/train.csv')

# %%
train_data=train_data.sample(n=500,random_state=0)
train_data.head()
# Out:
#        age workclass  fnlwgt      education  education-num  \
# 6118    51   Private   39264   Some-college             10
# 23204   58   Private   51662           10th              6
# 29590   40   Private  326310   Some-college             10
# 18116   37   Private  222450        HS-grad              9
# 33964   62   Private  109190      Bachelors             13
#
#             marital-status        occupation    relationship    race      sex  \
# 6118    Married-civ-spouse   Exec-managerial            Wife   White   Female
# 23204   Married-civ-spouse     Other-service            Wife   White   Female
# 29590   Married-civ-spouse      Craft-repair         Husband   White     Male
# 18116        Never-married             Sales   Not-in-family   White     Male
# 33964   Married-civ-spouse   Exec-managerial         Husband   White     Male
#
#        capital-gain  capital-loss  hours-per-week  native-country   class
# 6118              0             0              40   United-States    >50K
# 23204             0             0               8   United-States   <=50K
# 29590             0             0              44   United-States   <=50K
# 18116             0          2339              40     El-Salvador   <=50K
# 33964         15024             0              40   United-States    >50K

# %% [markdown]
# ## train

# %%
label = 'class'
save_path = '../models/AutogluonModels'  
predictor = TabularPredictor(label=label, path=save_path).fit(train_data)
# Out:
# Beginning AutoGluon training ...
# AutoGluon will save models to "../models/AutogluonModels/"
# AutoGluon Version:  0.2.0
# Train Data Rows:    500
# Train Data Columns: 14
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [' >50K', ' <=50K']
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 =  >50K, class 0 =  <=50K
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive ( >50K) vs negative ( <=50K) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    9486.35 MB
# 	Train Data (Original)  Memory Usage: 0.29 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('int', [])    : 6 | ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', ...]
# 		('object', []) : 8 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) : 8 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 		('int', [])      : 6 | ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', ...]
# 	0.1s = Fit runtime
# 	14 features in original data used to generate 14 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.03 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.09s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric argument of fit()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 400, Val Rows: 100
# Fitting model: KNeighborsUnif ...
# 	0.73	 = Validation accuracy score
# 	0.0s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	0.65	 = Validation accuracy score
# 	0.0s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMXT ...
# 	0.83	 = Validation accuracy score
# 	0.3s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM ...
# 	0.85	 = Validation accuracy score
# 	1.26s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestGini ...
# 	0.84	 = Validation accuracy score
# 	1.0s	 = Training runtime
# 	0.07s	 = Validation runtime
# Fitting model: RandomForestEntr ...
# 	0.83	 = Validation accuracy score
# 	0.99s	 = Training runtime
# 	0.07s	 = Validation runtime
# Fitting model: CatBoost ...
# 	0.84	 = Validation accuracy score
# 	0.35s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesGini ...
# 	0.82	 = Validation accuracy score
# 	1.0s	 = Training runtime
# 	0.08s	 = Validation runtime
# Fitting model: ExtraTreesEntr ...
# 	0.82	 = Validation accuracy score
# 	1.0s	 = Training runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# /workspaces/load_to_goal/GitHub/machine-learning/.venv/lib/python3.8/site-packages/torch/cuda/__init__.py:52: UserWarning: CUDA initialization: Found no NVIDIA driver on your system. Please check that you have an NVIDIA GPU and installed a driver from http://www.nvidia.com/Download/index.aspx (Triggered internally at  /pytorch/c10/cuda/CUDAFunctions.cpp:100.)
#   return torch._C._cuda_getDeviceCount() > 0
# 	0.83	 = Validation accuracy score
# 	1.6s	 = Training runtime
# 	0.03s	 = Validation runtime
# Fitting model: XGBoost ...
# 	0.85	 = Validation accuracy score
# 	0.13s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetMXNet ...
# 	0.84	 = Validation accuracy score
# 	5.11s	 = Training runtime
# 	0.09s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	0.83	 = Validation accuracy score
# 	1.21s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	0.85	 = Validation accuracy score
# 	0.38s	 = Training runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 15.67s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("../models/AutogluonModels/")

# %% [markdown]
# ## load test data

# %%
test_data = TabularDataset('https://autogluon.s3.amazonaws.com/datasets/Inc/test.csv')
y_test = test_data[label]  
test_data_nolab = test_data.drop(columns=[label])  
test_data_nolab.head()
# Out:
# Loaded data from: https://autogluon.s3.amazonaws.com/datasets/Inc/test.csv | Columns = 15 / 15 | Rows = 9769 -> 9769
#    age          workclass  fnlwgt      education  education-num  \
# 0   31            Private  169085           11th              7
# 1   17   Self-emp-not-inc  226203           12th              8
# 2   47            Private   54260      Assoc-voc             11
# 3   21            Private  176262   Some-college             10
# 4   17            Private  241185           12th              8
#
#         marital-status        occupation relationship    race      sex  \
# 0   Married-civ-spouse             Sales         Wife   White   Female
# 1        Never-married             Sales    Own-child   White     Male
# 2   Married-civ-spouse   Exec-managerial      Husband   White     Male
# 3        Never-married   Exec-managerial    Own-child   White   Female
# 4        Never-married    Prof-specialty    Own-child   White     Male
#
#    capital-gain  capital-loss  hours-per-week  native-country
# 0             0             0              20   United-States
# 1             0             0              45   United-States
# 2             0          1887              60   United-States
# 3             0             0              30   United-States
# 4             0             0              20   United-States

# %% [markdown]
# ## predict

# %%
y_pred=predictor.predict(test_data_nolab)
pred_probs = predictor.predict_proba(test_data_nolab)

# %%
y_pred
# Out:
# 0        <=50K
# 1        <=50K
# 2         >50K
# 3        <=50K
# 4        <=50K
#          ...
# 9764     <=50K
# 9765     <=50K
# 9766     <=50K
# 9767     <=50K
# 9768     <=50K
# Name: class, Length: 9769, dtype: object

# %%
pred_probs.head(5)
# Out:
#       <=50K      >50K
# 0  0.949797  0.050203
# 1  0.945973  0.054027
# 2  0.433299  0.566701
# 3  0.991393  0.008607
# 4  0.949908  0.050092

# %%
perf = predictor.evaluate_predictions(y_true=y_test, y_pred=y_pred, auxiliary_metrics=True)
# Out:
# Evaluation: accuracy on test data: 0.8397993653393387
# Evaluations on test data:
# {
#     "accuracy": 0.8397993653393387,
#     "balanced_accuracy": 0.7437076677780596,
#     "mcc": 0.5295565206264157,
#     "f1": 0.6242496998799519,
#     "precision": 0.7038440714672441,
#     "recall": 0.5608283002588438
# }

# %%
predictor.leaderboard(test_data,silent=True)
# Out:
#                   model  score_test  score_val  pred_time_test  pred_time_val  \
# 0               XGBoost    0.842666       0.85        0.070455       0.005955
# 1      RandomForestGini    0.841335       0.84        0.210777       0.074643
# 2      RandomForestEntr    0.840721       0.83        0.226019       0.072760
# 3              LightGBM    0.839799       0.85        0.019053       0.011646
# 4   WeightedEnsemble_L2    0.839799       0.85        0.021561       0.012201
# 5            LightGBMXT    0.839390       0.83        0.021128       0.013353
# 6              CatBoost    0.837957       0.84        0.017886       0.010824
# 7        ExtraTreesEntr    0.834783       0.82        0.199178       0.073653
# 8        ExtraTreesGini    0.834476       0.82        0.216009       0.075349
# 9         LightGBMLarge    0.827823       0.83        0.022927       0.013216
# 10       NeuralNetMXNet    0.824752       0.84        7.661630       0.085673
# 11      NeuralNetFastAI    0.821783       0.83        0.207850       0.029907
# 12       KNeighborsUnif    0.725970       0.73        0.019064       0.008799
# 13       KNeighborsDist    0.695158       0.65        0.022603       0.007534
#
#     fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0   0.133345                 0.070455                0.005955
# 1   1.000353                 0.210777                0.074643
# 2   0.988837                 0.226019                0.072760
# 3   1.263745                 0.019053                0.011646
# 4   1.648108                 0.002508                0.000555
# 5   0.300615                 0.021128                0.013353
# 6   0.354236                 0.017886                0.010824
# 7   0.998703                 0.199178                0.073653
# 8   0.995111                 0.216009                0.075349
# 9   1.211954                 0.022927                0.013216
# 10  5.111636                 7.661630                0.085673
# 11  1.601153                 0.207850                0.029907
# 12  0.003603                 0.019064                0.008799
# 13  0.003029                 0.022603                0.007534
#
#     fit_time_marginal  stack_level  can_infer  fit_order
# 0            0.133345            1       True         11
# 1            1.000353            1       True          5
# 2            0.988837            1       True          6
# 3            1.263745            1       True          4
# 4            0.384363            2       True         14
# 5            0.300615            1       True          3
# 6            0.354236            1       True          7
# 7            0.998703            1       True          9
# 8            0.995111            1       True          8
# 9            1.211954            1       True         13
# 10           5.111636            1       True         12
# 11           1.601153            1       True         10
# 12           0.003603            1       True          1
# 13           0.003029            1       True          2

# %%
predictor.problem_type
# Out:
# 'binary'

# %%
predictor.feature_metadata

# %% [markdown]
# ## maximizing predictive performance

# %%
time_limit = 10
metric = 'roc_auc'  
predictor = TabularPredictor(label, eval_metric=metric,path="../models/AutogluonModels").fit(train_data, time_limit=time_limit, presets='best_quality')
predictor.leaderboard(test_data, silent=True)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="../models/AutogluonModels"
# Presets specified: ['best_quality']
# Beginning AutoGluon training ... Time limit = 10s
# AutoGluon will save models to "../models/AutogluonModels/"
# AutoGluon Version:  0.2.0
# Train Data Rows:    500
# Train Data Columns: 14
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [' >50K', ' <=50K']
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 =  >50K, class 0 =  <=50K
# 	Note: For your binary classification, AutoGluon arbitrarily selected which label-value represents positive ( >50K) vs negative ( <=50K) class.
# 	To explicitly set the positive_class, either rename classes to 1 and 0, or specify positive_class in Predictor init.
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    9711.9 MB
# 	Train Data (Original)  Memory Usage: 0.29 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('int', [])    : 6 | ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', ...]
# 		('object', []) : 8 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) : 8 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 		('int', [])      : 6 | ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', ...]
# 	0.1s = Fit runtime
# 	14 features in original data used to generate 14 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.03 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.08s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'roc_auc'
# 	This metric expects predicted probabilities rather than predicted class labels, so you'll need to use predict_proba() instead of predict()
# 	To change this, specify the eval_metric argument of fit()
# Fitting model: KNeighborsUnif_BAG_L1 ... Training model for up to 9.92s of the 9.91s of remaining time.
# 	0.5196	 = Validation roc_auc score
# 	0.0s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: KNeighborsDist_BAG_L1 ... Training model for up to 9.9s of the 9.89s of remaining time.
# 	0.537	 = Validation roc_auc score
# 	0.0s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 9.88s of the 9.88s of remaining time.
# 	0.8814	 = Validation roc_auc score
# 	0.89s	 = Training runtime
# 	0.06s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 8.9s of the 8.9s of remaining time.
# 	0.867	 = Validation roc_auc score
# 	2.3s	 = Training runtime
# 	0.07s	 = Validation runtime
# Fitting model: RandomForestGini_BAG_L1 ... Training model for up to 6.5s of the 6.49s of remaining time.
# 	0.8847	 = Validation roc_auc score
# 	0.96s	 = Training runtime
# 	0.08s	 = Validation runtime
# Fitting model: RandomForestEntr_BAG_L1 ... Training model for up to 5.43s of the 5.42s of remaining time.
# 	0.8863	 = Validation roc_auc score
# 	1.03s	 = Training runtime
# 	0.1s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 4.27s of the 4.27s of remaining time.
# 	0.8875	 = Validation roc_auc score
# 	2.64s	 = Training runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTreesGini_BAG_L1 ... Training model for up to 1.56s of the 1.56s of remaining time.
# 	0.8929	 = Validation roc_auc score
# 	1.0s	 = Training runtime
# 	0.09s	 = Validation runtime
# Fitting model: ExtraTreesEntr_BAG_L1 ... Training model for up to 0.45s of the 0.45s of remaining time.
# 	0.8939	 = Validation roc_auc score
# 	1.01s	 = Training runtime
# 	0.09s	 = Validation runtime
# Completed 1/20 k-fold bagging repeats ...
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 9.92s of the -0.68s of remaining time.
# 	0.8994	 = Validation roc_auc score
# 	0.89s	 = Training runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 11.58s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("../models/AutogluonModels/")
#                      model  score_test  score_val  pred_time_test  \
# 0          CatBoost_BAG_L1    0.902783   0.887489        0.067369
# 1        LightGBMXT_BAG_L1    0.900161   0.881380        0.121851
# 2      WeightedEnsemble_L2    0.898389   0.899442        0.855168
# 3          LightGBM_BAG_L1    0.892347   0.866991        0.073432
# 4  RandomForestEntr_BAG_L1    0.888119   0.886301        0.223592
# 5  RandomForestGini_BAG_L1    0.886598   0.884698        0.225724
# 6    ExtraTreesGini_BAG_L1    0.881065   0.892927        0.186173
# 7    ExtraTreesEntr_BAG_L1    0.880851   0.893912        0.251829
# 8    KNeighborsDist_BAG_L1    0.525998   0.536956        0.020430
# 9    KNeighborsUnif_BAG_L1    0.514970   0.519604        0.019319
#
#    pred_time_val  fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0       0.045379  2.636528                 0.067369                0.045379
# 1       0.055607  0.891131                 0.121851                0.055607
# 2       0.384333  7.455956                 0.004354                0.001101
# 3       0.071198  2.298749                 0.073432                0.071198
# 4       0.099532  1.034022                 0.223592                0.099532
# 5       0.083766  0.963602                 0.225724                0.083766
# 6       0.090512  0.995592                 0.186173                0.090512
# 7       0.092202  1.010175                 0.251829                0.092202
# 8       0.008027  0.001714                 0.020430                0.008027
# 9       0.009029  0.002117                 0.019319                0.009029
#
#    fit_time_marginal  stack_level  can_infer  fit_order
# 0           2.636528            1       True          7
# 1           0.891131            1       True          3
# 2           0.888509            2       True         10
# 3           2.298749            1       True          4
# 4           1.034022            1       True          6
# 5           0.963602            1       True          5
# 6           0.995592            1       True          8
# 7           1.010175            1       True          9
# 8           0.001714            1       True          2
# 9           0.002117            1       True          1

# %% [markdown]
# ## regression

# %%
age_column="age"
predictor_age=TabularPredictor(label=age_column,path="../models/AutogluonModels").fit(train_data)
performance = predictor_age.evaluate(test_data)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="../models/AutogluonModels"
# Beginning AutoGluon training ...
# AutoGluon will save models to "../models/AutogluonModels/"
# AutoGluon Version:  0.2.0
# Train Data Rows:    500
# Train Data Columns: 14
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == int and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (85, 17, 39.652, 13.52393)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    9679.16 MB
# 	Train Data (Original)  Memory Usage: 0.32 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('int', [])    : 5 | ['fnlwgt', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week']
# 		('object', []) : 9 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', []) : 9 | ['workclass', 'education', 'marital-status', 'occupation', 'relationship', ...]
# 		('int', [])      : 5 | ['fnlwgt', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week']
# 	0.1s = Fit runtime
# 	14 features in original data used to generate 14 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.03 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.09s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	To change this, specify the eval_metric argument of fit()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 400, Val Rows: 100
# Fitting model: KNeighborsUnif ...
# 	-15.6869	 = Validation root_mean_squared_error score
# 	0.0s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	-15.1801	 = Validation root_mean_squared_error score
# 	0.0s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMXT ...
# 	-11.8147	 = Validation root_mean_squared_error score
# 	0.19s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM ...
# 	-11.9295	 = Validation root_mean_squared_error score
# 	0.17s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestMSE ...
# 	-11.6028	 = Validation root_mean_squared_error score
# 	0.8s	 = Training runtime
# 	0.07s	 = Validation runtime
# Fitting model: CatBoost ...
# 	-11.9166	 = Validation root_mean_squared_error score
# 	0.4s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesMSE ...
# 	-11.4808	 = Validation root_mean_squared_error score
# 	0.92s	 = Training runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	-40.4725	 = Validation root_mean_squared_error score
# 	1.06s	 = Training runtime
# 	0.04s	 = Validation runtime
# Fitting model: XGBoost ...
# 	-12.1743	 = Validation root_mean_squared_error score
# 	2.06s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetMXNet ...
# 	-12.5157	 = Validation root_mean_squared_error score
# 	18.29s	 = Training runtime
# 	0.17s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	-12.1676	 = Validation root_mean_squared_error score
# 	1.47s	 = Training runtime
# 	0.01s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-11.2633	 = Validation root_mean_squared_error score
# 	0.53s	 = Training runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 27.06s ...
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("../models/AutogluonModels/")
# Evaluation: root_mean_squared_error on test data: -10.541612959704214
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "root_mean_squared_error": -10.541612959704214,
#     "mean_squared_error": -111.12560379220382,
#     "mean_absolute_error": -8.236940963398363,
#     "r2": 0.4060120760549193,
#     "pearsonr": 0.6374175053521758,
#     "median_absolute_error": -6.842052459716797
# }

# %%
predictor_age.leaderboard(test_data, silent=True)
# Out:
#                   model  score_test  score_val  pred_time_test  pred_time_val  \
# 0   WeightedEnsemble_L2  -10.541613 -11.263276        8.330542       0.349694
# 1              CatBoost  -10.579617 -11.916622        0.025914       0.011271
# 2         ExtraTreesMSE  -10.691115 -11.480752        0.169004       0.068667
# 3       RandomForestMSE  -10.746518 -11.602848        0.154411       0.067874
# 4            LightGBMXT  -10.753344 -11.814712        0.048232       0.012587
# 5              LightGBM  -10.972156 -11.929546        0.029070       0.011835
# 6               XGBoost  -11.121008 -12.174270        0.078902       0.008004
# 7         LightGBMLarge  -11.598649 -12.167606        0.053989       0.012129
# 8        NeuralNetMXNet  -11.861902 -12.515734        7.827150       0.171145
# 9        KNeighborsUnif  -14.902058 -15.686937        0.019096       0.007803
# 10       KNeighborsDist  -15.771259 -15.180149        0.019312       0.009116
# 11      NeuralNetFastAI  -39.140348 -40.472548        0.211450       0.036723
#
#      fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0   22.961126                 0.004460                0.000467
# 1    0.398379                 0.025914                0.011271
# 2    0.917422                 0.169004                0.068667
# 3    0.801137                 0.154411                0.067874
# 4    0.190649                 0.048232                0.012587
# 5    0.170528                 0.029070                0.011835
# 6    2.059135                 0.078902                0.008004
# 7    1.473360                 0.053989                0.012129
# 8   18.288753                 7.827150                0.171145
# 9    0.002781                 0.019096                0.007803
# 10   0.003363                 0.019312                0.009116
# 11   1.061826                 0.211450                0.036723
#
#     fit_time_marginal  stack_level  can_infer  fit_order
# 0            0.530138            2       True         12
# 1            0.398379            1       True          6
# 2            0.917422            1       True          7
# 3            0.801137            1       True          5
# 4            0.190649            1       True          3
# 5            0.170528            1       True          4
# 6            2.059135            1       True          9
# 7            1.473360            1       True         11
# 8           18.288753            1       True         10
# 9            0.002781            1       True          1
# 10           0.003363            1       True          2
# 11           1.061826            1       True          8
